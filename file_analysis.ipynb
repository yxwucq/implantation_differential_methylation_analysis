# %%
import pandas as pd

# %%
df = pd.read_csv("file_analysis.xls", sep=" +", header=None, engine='python')
positive_list = pd.read_csv("./data/P_list0617.txt", header=None)
negative_list = pd.read_csv("./data/N_list0617.txt", header=None)
df['name'] = df[8].str.extract(r'/data/(.*).single5mC')
# Out:
#                 0
# 0   PBAT_E101_B10
# 1   PBAT_E107_B10
# 2   PBAT_E109_B11
# 3   PBAT_E110_B11
# 4   PBAT_E112_B11
# ..            ...
# 59    PBAT_E87_B9
# 60    PBAT_E88_B9
# 61    PBAT_E89_B9
# 62    PBAT_E91_B9
# 63   PBAT_E96_B10
#
# [64 rows x 1 columns]

# %%
negative_list
# Out:
#                 0
# 0     PBAT_E16_B2
# 1     PBAT_E17_B2
# 2     PBAT_E18_B2
# 3     PBAT_E22_B3
# 4    PBAT_E41_F14
# 5    PBAT_E42_F15
# 6    PBAT_E44_F17
# 7    PBAT_E46_F19
# 8    PBAT_E49_F22
# 9    PBAT_E53_F26
# 10   PBAT_E54_F27
# 11    PBAT_E76_B9
# 12    PBAT_E77_B9
# 13    PBAT_E78_B9
# 14    PBAT_E80_B9
# 15    PBAT_E86_B9
# 16    PBAT_E87_B9
# 17    PBAT_E88_B9
# 18    PBAT_E89_B9
# 19    PBAT_E91_B9
# 20  PBAT_E107_B10
# 21  PBAT_E109_B11
# 22  PBAT_E110_B11
# 23  PBAT_E112_B11
# 24  PBAT_E116_B11
# 25  PBAT_E118_B11
# 26  PBAT_E125_B11
# 27  PBAT_E126_B11
# 28  PBAT_E127_B11
# 29  PBAT_E129_B11
# 30  PBAT_E145_B12
# 31  PBAT_E146_B12
# 32  PBAT_E150_B12
# 33  PBAT_E152_B12
# 34  PBAT_E156_B12
# 35  PBAT_E178_B13
# 36  PBAT_E180_B13
# 37  PBAT_E183_B13
# 38  PBAT_E185_B13
# 39  PBAT_E188_B13
# 40  PBAT_E189_B13
# 41  PBAT_E192_B13
# 42  PBAT_E194_B13
# 43  PBAT_E197_B13
# 44  PBAT_E200_B13
# 45  PBAT_E202_B13
